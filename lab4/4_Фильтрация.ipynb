# %% [markdown]
# # Лабораторная работа №4: Знакомство с OpenCV и обработка изображений
#
# **Цель**: Освоить базовые операции с изображениями: чтение, запись, цветовые преобразования, фильтрация, улучшение контраста.
#
# **Задачи**:
# 1. Загрузить изображение.
# 2. Преобразовать в оттенки серого, HSV.
# 3. Применить фильтры (размытие, шумоподавление).
# 4. Применить CLAHE для улучшения контраста.
#
# **Примечание**: Используйте своё изображение или стандартное (например, `opencv-logo.png`).

# %%
# !pip install opencv-python matplotlib numpy

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 1. Загрузка изображения

# %%
# ЗАДАНИЕ: загрузите изображение с диска
img_path = '1_lenna.png'  # <-- укажите путь
img = None  # <-- используйте cv2.imread

# %% [markdown]
# ## 2. Преобразование цветовых пространств

# %%
# ЗАДАНИЕ: преобразуйте в grayscale и HSV
gray = None  # <-- cv2.cvtColor(..., cv2.COLOR_BGR2GRAY)
hsv = None   # <-- cv2.cvtColor(..., cv2.COLOR_BGR2HSV)

# %% [markdown]
# ## 3. Применение фильтров

# %%
# ЗАДАНИЕ: примените GaussianBlur и medianBlur
blurred_gauss = None  # <-- cv2.GaussianBlur
blurred_median = None # <-- cv2.medianBlur

# %% [markdown]
# ## 4. Улучшение контраста с CLAHE

# %%
# ЗАДАНИЕ: примените CLAHE к grayscale-изображению
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = None  # <-- clahe.apply(gray)

# %% [markdown]
# ## 5. Визуализация

# %%
images = [img, gray, blurred_gauss, cl1]
titles = ['Original', 'Grayscale', 'Gaussian Blur', 'CLAHE']

plt.figure(figsize=(14, 4))
for i in range(len(images)):
    plt.subplot(1, 4, i+1)
    if len(images[i].shape) == 3:
        plt.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
    else:
        plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')
plt.show()

# %% [markdown]
# ## Выводы
#
# Какие фильтры лучше справляются с шумом? В каких случаях CLAHE даёт заметный эффект?

# %% [markdown]
# ## Контрольные вопросы
#
# 1. В чём разница между цветовыми пространствами RGB, HSV и LAB? Когда предпочтительно использовать HSV?
# 2. Почему при работе с OpenCV изображения часто загружаются в формате BGR, а не RGB?
# 3. Как работает фильтр Гаусса? Чем он отличается от медианного фильтра по воздействию на шум?
# 4. Что такое динамический диапазон изображения и как его можно расширить?
# 5. В чём суть метода CLAHE? Чем он лучше глобального выравнивания гистограммы?
# 6. Какие типы шумов встречаются в изображениях (например, с камер наблюдения на нефтегазовых объектах)? Какие фильтры эффективны против каждого типа?
# 7. Почему при применении фильтров важно учитывать размер ядра (kernel size)?
# 8. Как преобразование в оттенки серого может повлиять на последующую обработку изображения?
